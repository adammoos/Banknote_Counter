# %%
# %pip install roboflow
# Out:
# Requirement already satisfied: roboflow in c:\users\gigabyte\anaconda3\lib\site-packages (1.2.11)
# Requirement already satisfied: certifi in c:\users\gigabyte\anaconda3\lib\site-packages (from roboflow) (2025.4.26)
# Requirement already satisfied: idna==3.7 in c:\users\gigabyte\anaconda3\lib\site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in c:\users\gigabyte\anaconda3\lib\site-packages (from roboflow) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gigabyte\anaconda3\lib\site-packages (from roboflow) (1.4.8)
# Requirement already satisfied: matplotlib in c:\users\gigabyte\anaconda3\lib\site-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\gigabyte\anaconda3\lib\site-packages (from roboflow) (2.1.3)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in c:\users\gigabyte\anaconda3\lib\site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\gigabyte\anaconda3\lib\site-packages (from roboflow) (11.1.0)
# Requirement already satisfied: pi-heif<2 in c:\users\gigabyte\anaconda3\lib\site-packages (from roboflow) (1.1.1)
# Requirement already satisfied: pillow-avif-plugin<2 in c:\users\gigabyte\anaconda3\lib\site-packages (from roboflow) (1.5.2)
# Requirement already satisfied: python-dateutil in c:\users\gigabyte\anaconda3\lib\site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in c:\users\gigabyte\anaconda3\lib\site-packages (from roboflow) (1.1.0)
# Requirement already satisfied: requests in c:\users\gigabyte\anaconda3\lib\site-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in c:\users\gigabyte\anaconda3\lib\site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in c:\users\gigabyte\anaconda3\lib\site-packages (from roboflow) (2.3.0)
# Requirement already satisfied: tqdm>=4.41.0 in c:\users\gigabyte\anaconda3\lib\site-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\gigabyte\anaconda3\lib\site-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in c:\users\gigabyte\anaconda3\lib\site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in c:\users\gigabyte\anaconda3\lib\site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: colorama in c:\users\gigabyte\anaconda3\lib\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gigabyte\anaconda3\lib\site-packages (from matplotlib->roboflow) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gigabyte\anaconda3\lib\site-packages (from matplotlib->roboflow) (4.55.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\gigabyte\anaconda3\lib\site-packages (from matplotlib->roboflow) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\gigabyte\anaconda3\lib\site-packages (from matplotlib->roboflow) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\gigabyte\anaconda3\lib\site-packages (from requests->roboflow) (3.3.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="4sbzhohchgMCJbefg7dh")
project = rf.workspace("tatmantech").project("worldwide_currency")
version = project.version(5)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in worldwide_currency-5 to yolov8:: 100%|██████████| 227328/227328 [05:44<00:00, 659.16it/s]
# Extracting Dataset Version Zip to worldwide_currency-5 in yolov8::   0%|          | 10/9854 [00:00<02:10, 75.42it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 6
#       4 project = rf.workspace("tatmantech").project("worldwide_currency")
#       5 version = project.version(5)
# ----> 6 dataset = version.download("yolov8")
#
# File c:\Users\GIGABYTE\anaconda3\Lib\site-packages\roboflow\core\version.py:242, in Version.download(self, model_format, location, overwrite)
#     239     link = export_info["export"]["link"]
#     241 self.__download_zip(link, location, model_format)
# --> 242 self.__extract_zip(location, model_format)
#     243 self.__reformat_yaml(location, model_format)  # TODO: is roboflow-python a place to be munging yaml files?
#     245 return Dataset(self.name, self.version, model_format, os.path.abspath(location))
#
# File c:\Users\GIGABYTE\anaconda3\Lib\site-packages\roboflow\core\version.py:598, in Version.__extract_zip(self, location, format)
#     593 for member in tqdm(
#     594     zip_ref.infolist(),
#     595     desc=desc,
#     596 ):
#     597     try:
# --> 598         zip_ref.extract(member, location)
#     599     except zipfile.error:
#     600         raise RuntimeError("Error unzipping download")
#
# File c:\Users\GIGABYTE\anaconda3\Lib\zipfile\__init__.py:1770, in ZipFile.extract(self, member, path, pwd)
#    1767 else:
#    1768     path = os.fspath(path)
# -> 1770 return self._extract_member(member, path, pwd)
#
# File c:\Users\GIGABYTE\anaconda3\Lib\zipfile\__init__.py:1849, in ZipFile._extract_member(self, member, targetpath, pwd)
#    1845                 raise
#    1846     return targetpath
#    1848 with self.open(member, pwd=pwd) as source, \
# -> 1849      open(targetpath, "wb") as target:
#    1850     shutil.copyfileobj(source, target)
#    1852 return targetpath
#
# FileNotFoundError: [Errno 2] No such file or directory: 'worldwide_currency-5\\test\\images\\100-2Brupees-2BPeacock-2BNote-2B1949-2BReserve-2BBank-2Bof-2BIndia-2Bbanknote-2Bfor-2BBurma_JPG.rf.3cc9954c601c193a671d4ee630794b38.jpg'

# %%
# %pip install ultralytics
import subprocess

subprocess.run([
    "yolo", "train",
    "data=worldwide_currency/data.yaml",
    "model=yolov8n.pt",
    "epochs=50",
    "imgsz=640"
])

# %%
# !ls /content/datasets/worldwide_currency-5/

# %%
from ultralytics import YOLO

# Load YOLOv8 model
model = YOLO("yolov8n.pt")

# Train on the downloaded dataset
model.train(data="/content/datasets/worldwide_currency-5/data.yaml", epochs=10, imgsz=640)

# %%
from ultralytics import YOLO
import cv2
from google.colab.patches import cv2_imshow

# Load the trained YOLO model
model = YOLO("yolo11n.pt")

# Load an image for testing
image_path = "coins.png"
image = cv2.imread(image_path)

results = model(image)

for result in results:
    for box in result.boxes.xyxy:
        x1, y1, x2, y2 = map(int, box)
        cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 3)

# Save and display result
cv2.imwrite("money_detected.png", image)
cv2_imshow(image)

# %%
from ultralytics import YOLO

# Load the trained YOLOv8 model
model = YOLO("/content/runs/detect/train10/weights/best.pt")

# Export the model to TensorRT format (for NVIDIA GPU acceleration)
model.export(format="engine")  # Converts model to TensorRT (.engine)

# %%
from ultralytics import YOLO

# Load the trained YOLOv8 model
model = YOLO("/content/runs/detect/train10/weights/best.pt")

model.export(format="torchscript")  # Converts model to TorchScript (.pt)

# %%
from ultralytics import YOLO
import cv2
from google.colab.patches import cv2_imshow

# Load the trained YOLO model
model = YOLO("/content/runs/detect/train10/weights/best.pt")

# Load an image for testing
image_path = "banknotes.png"
image = cv2.imread(image_path)

results = model(image)

for result in results:
    for box in result.boxes.xyxy:
        x1, y1, x2, y2 = map(int, box)
        cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 3)

# Save and display result
cv2.imwrite("money_detected.png", image)
cv2_imshow(image)

# %%
image_path = "banknotes1.jpg"
image = cv2.imread(image_path)

results = model(image)

for result in results:
    for box in result.boxes.xyxy:
        x1, y1, x2, y2 = map(int, box)
        cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 3)

# Save and display result
cv2.imwrite("money_detected.png", image)
cv2_imshow(image)
